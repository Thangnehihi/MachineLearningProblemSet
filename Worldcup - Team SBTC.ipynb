# %% [markdown]
# # Team 6 - World Cup
#
# ![](https://img.fifa.com/image/upload/t_l4/v1543921822/ex1ksdevyxwsgu7rzdv6.jpg)
#
# _For more information about the dataset, read [here](https://www.kaggle.com/abecklas/fifa-world-cup)._
#
# ## Your tasks
# - Name your team!
# - Read the source and do some quick research to understand more about the dataset and its topic
# - Clean the data
# - Perform Exploratory Data Analysis on the dataset
# - Analyze the data more deeply and extract insights
# - Visualize your analysis on Google Data Studio
# - Present your works in front of the class and guests next Monday
#
# ## Submission Guide
# - Create a Github repository for your project
# - Upload the dataset (.csv file) and the Jupyter Notebook to your Github repository. In the Jupyter Notebook, **include the link to your Google Data Studio report**.
# - Submit your works through this [Google Form](https://forms.gle/oxtXpGfS8JapVj3V8).
#
# ## Tips for Data Cleaning, Manipulation & Visualization
# - Here are some of our tips for Data Cleaning, Manipulation & Visualization. [Click here](https://hackmd.io/cBNV7E6TT2WMliQC-GTw1A)
#
# _____________________________
#
# ## Some Hints for This Dataset:
# - Is there a way to integrate the data from all 3 datasets?
# - It seems like the `winners` dataset doesn't have data of World Cup 2018. Can you Google the relevant information and add it to the dataset using `pandas`?
# - The format of some number columns in `matches` dataset doesn't look right.
# - Can you seperate the Date and the Time of `Datetime` column in `matches` dataset?
# - And more...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
sns.set_style("whitegrid")

# %%
matches=pd.read_csv("https://raw.githubusercontent.com/Thangnehihi/MachineLearningProblemSet/master/matches.csv")
players=pd.read_csv("https://raw.githubusercontent.com/Thangnehihi/worldcup/master/players.csv")
winners=pd.read_csv("https://raw.githubusercontent.com/Thangnehihi/worldcup/master/winners.csv")

# %%
matches.head(1)
# Out:
#      Year              Datetime    Stage  Stadium         City Home Team Name  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1  Pocitos  Montevideo          France
#
#    Home Team Goals  Away Team Goals Away Team Name Win conditions  Attendance  \
# 0              4.0              1.0         Mexico                     4444.0
#
#    Half-time Home Goals  Half-time Away Goals                 Referee  \
# 0                   3.0                   0.0  LOMBARDI Domingo (URU)
#
#              Assistant 1          Assistant 2  RoundID  MatchID  \
# 0  CRISTOPHE Henry (BEL)  REGO Gilberto (BRA)    201.0   1096.0
#
#   Home Team Initials Away Team Initials
# 0                FRA                MEX

# %%
players.head(1)
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#    Player Name Position Event
# 0  Alex THEPOT       GK   NaN

# %%
print(players['MatchID'].isna().sum())
# Out:
# 0

# %%
matches['MatchID'].isna().sum()
# Out:
# 3720

# %%
len(players['MatchID'].unique())
# Out:
# 836

# %%
len(matches['MatchID'].unique())
# Out:
# 837

# %%
players[players['Event'].notna()]
# Out:
#        RoundID    MatchID Team Initials                 Coach Name Line-up  \
# 2          201       1096           FRA        CAUDRON Raoul (FRA)       S
# 3          201       1096           MEX           LUQUE Juan (MEX)       S
# 6          201       1096           FRA        CAUDRON Raoul (FRA)       S
# 14         201       1096           FRA        CAUDRON Raoul (FRA)       S
# 35         201       1090           USA           MILLAR Bob (USA)       S
# 41         201       1090           USA           MILLAR Bob (USA)       S
# 45         201       1090           USA           MILLAR Bob (USA)       S
# 73         201       1093           YUG      SIMONOVIC Bosko (YUG)       S
# 74         201       1093           BRA  DE CARVALHO Pindaro (BRA)       S
# 81         201       1093           YUG      SIMONOVIC Bosko (YUG)       S
# 112        201       1098           ROU        LUCHIDE Octav (ROU)       S
# 113        201       1098           PER        BRU Francisco (ESP)       S
# 116        201       1098           ROU        LUCHIDE Octav (ROU)       S
# 118        201       1098           ROU        LUCHIDE Octav (ROU)       S
# 127        201       1098           PER        BRU Francisco (ESP)       S
# 162        201       1085           ARG     OLAZAR Francisco (ARG)       S
# 189        201       1095           MEX           LUQUE Juan (MEX)       S
# 198        201       1095           CHI          ORTH Gyorgy (HUN)       S
# 220        201       1092           YUG      SIMONOVIC Bosko (YUG)       S
# 228        201       1092           YUG      SIMONOVIC Bosko (YUG)       S
# 234        201       1092           YUG      SIMONOVIC Bosko (YUG)       S
# 264        201       1097           USA           MILLAR Bob (USA)       S
# 292        201       1099           URU      SUPPICI Alberto (URU)       S
# 343        201       1094           CHI          ORTH Gyorgy (HUN)       S
# 374        201       1086           ARG     OLAZAR Francisco (ARG)       S
# 375        201       1086           MEX           LUQUE Juan (MEX)       S
# 384        201       1086           ARG     OLAZAR Francisco (ARG)       S
# 386        201       1086           ARG     OLAZAR Francisco (ARG)       S
# 389        201       1086           MEX           LUQUE Juan (MEX)       S
# 415        201       1091           BRA  DE CARVALHO Pindaro (BRA)       S
# ...        ...        ...           ...                        ...     ...
# 37700   255957  300186502           BRA  SCOLARI Luiz Felipe (BRA)       S
# 37701   255957  300186502           NED       Louis VAN GAAL (NED)       S
# 37703   255957  300186502           NED       Louis VAN GAAL (NED)       S
# 37704   255957  300186502           BRA  SCOLARI Luiz Felipe (BRA)       S
# 37705   255957  300186502           NED       Louis VAN GAAL (NED)       S
# 37706   255957  300186502           BRA  SCOLARI Luiz Felipe (BRA)       S
# 37707   255957  300186502           NED       Louis VAN GAAL (NED)       S
# 37711   255957  300186502           NED       Louis VAN GAAL (NED)       S
# 37713   255957  300186502           NED       Louis VAN GAAL (NED)       S
# 37715   255957  300186502           NED       Louis VAN GAAL (NED)       N
# 37719   255957  300186502           NED       Louis VAN GAAL (NED)       N
# 37720   255957  300186502           BRA  SCOLARI Luiz Felipe (BRA)       N
# 37723   255957  300186502           NED       Louis VAN GAAL (NED)       N
# 37724   255957  300186502           BRA  SCOLARI Luiz Felipe (BRA)       N
# 37732   255957  300186502           BRA  SCOLARI Luiz Felipe (BRA)       N
# 37740   255959  300186501           GER         LOEW Joachim (GER)       S
# 37744   255959  300186501           GER         LOEW Joachim (GER)       S
# 37746   255959  300186501           GER         LOEW Joachim (GER)       S
# 37747   255959  300186501           ARG    SABELLA Alejandro (ARG)       S
# 37748   255959  300186501           GER         LOEW Joachim (GER)       S
# 37749   255959  300186501           ARG    SABELLA Alejandro (ARG)       S
# 37753   255959  300186501           ARG    SABELLA Alejandro (ARG)       S
# 37758   255959  300186501           GER         LOEW Joachim (GER)       S
# 37759   255959  300186501           ARG    SABELLA Alejandro (ARG)       S
# 37767   255959  300186501           ARG    SABELLA Alejandro (ARG)       N
# 37768   255959  300186501           GER         LOEW Joachim (GER)       N
# 37776   255959  300186501           GER         LOEW Joachim (GER)       N
# 37777   255959  300186501           ARG    SABELLA Alejandro (ARG)       N
# 37778   255959  300186501           GER         LOEW Joachim (GER)       N
# 37781   255959  300186501           ARG    SABELLA Alejandro (ARG)       N
#
#        Shirt Number          Player Name Position           Event
# 2                 0     Marcel LANGILLER      NaN            G40'
# 3                 0         Juan CARRENO      NaN            G70'
# 6                 0      Andre MASCHINOT      NaN       G43' G87'
# 14                0       Lucien LAURENT      NaN            G19'
# 35                0           Tom FLORIE        C            G45'
# 41                0          Bart McGHEE      NaN            G23'
# 45                0       Bert PATENAUDE      NaN            G69'
# 73                0            Ivica BEK      NaN            G30'
# 74                0            PREGUINHO        C            G62'
# 81                0  Aleksandar TIRNANIC      NaN            G21'
# 112               0        Adalbert DESU      NaN             G1'
# 113               0      Placido GALINDO        C            R70'
# 116               0       Nicolae KOVACS      NaN            G89'
# 118               0   Constantin STANCIU      NaN            G79'
# 127               0           Luis SOUZA      NaN            G75'
# 162               0           Luis MONTI      NaN            G81'
# 189               0         Manuel ROSAS      NaN            W51'
# 198               0         Carlos VIDAL      NaN        G3' G65'
# 220               0   Blagoje MARJANOVIC      NaN            G65'
# 228               0  Djordje VUJADINOVIC      NaN            G85'
# 234               0            Ivica BEK      NaN       G60' G67'
# 264               0       Bert PATENAUDE      NaN  G10' G15' G50'
# 292               0        Hector CASTRO      NaN            G60'
# 343               0   Guillermo SUBIABRE      NaN            G65'
# 374               0    Francisco VARALLO      NaN            G53'
# 375               0        Roberto GAYON      NaN            G75'
# 384               0       Adolfo ZUMELZU      NaN       G12' G55'
# 386               0    Guillermo STABILE      NaN   G8' G17' G80'
# 389               0         Manuel ROSAS      NaN       P42' G65'
# 415               0            PREGUINHO        C       G67' G83'
# ...             ...                  ...      ...             ...
# 37700            11                OSCAR      NaN            Y68'
# 37701             5                BLIND      NaN       G17' O70'
# 37703             8            DE GUZMAN      NaN            Y36'
# 37704            16              RAMIRES      NaN            O73'
# 37705             9            V. PERSIE        C             P3'
# 37706            17            L GUSTAVO      NaN           OH46'
# 37707            11               ROBBEN      NaN             Y9'
# 37711            16               CLASIE      NaN            O90'
# 37713            20            WIJNALDUM      NaN            G90'
# 37715            22                 VORM       GK            I90'
# 37719             7              JANMAAT      NaN            I70'
# 37720             5          FERNANDINHO      NaN      IH46' Y54'
# 37723            13              VELTMAN      NaN            I90'
# 37724             7                 HULK      NaN            I73'
# 37732            18             HERNANES      NaN            I57'
# 37740             4              H�WEDES      NaN            Y34'
# 37744             7       SCHWEINSTEIGER      NaN            Y29'
# 37746             8                 �ZIL      NaN           O120'
# 37747             8                PEREZ      NaN            O86'
# 37748            11                KLOSE      NaN            O88'
# 37749             9              HIGUAIN      NaN            O78'
# 37753            14           MASCHERANO      NaN            Y64'
# 37758            23               KRAMER      NaN            O31'
# 37759            22              LAVEZZI      NaN           OH46'
# 37767             5                 GAGO      NaN            I86'
# 37768             9             SCH�RRLE      NaN            I31'
# 37776            17          MERTESACKER      NaN           I120'
# 37777            18              PALACIO      NaN            I78'
# 37778            19                G�TZE      NaN      I88' G113'
# 37781            20               AGUERO      NaN      IH46' Y65'
#
# [9069 rows x 9 columns]

# %%
matches[matches['MatchID']==1096]
# Out:
#      Year              Datetime    Stage  Stadium         City Home Team Name  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1  Pocitos  Montevideo          France
#
#    Home Team Goals  Away Team Goals Away Team Name Win conditions  Attendance  \
# 0              4.0              1.0         Mexico                     4444.0
#
#    Half-time Home Goals  Half-time Away Goals                 Referee  \
# 0                   3.0                   0.0  LOMBARDI Domingo (URU)
#
#              Assistant 1          Assistant 2  RoundID  MatchID  \
# 0  CRISTOPHE Henry (BEL)  REGO Gilberto (BRA)    201.0   1096.0
#
#   Home Team Initials Away Team Initials
# 0                FRA                MEX

# %%
matches.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# min                0.000000              0.000000  2.010000e+02  2.500000e+01
# 25%                0.000000              0.000000  2.620000e+02  1.188750e+03
# 50%                0.000000              0.000000  3.370000e+02  2.191000e+03
# 75%                1.000000              1.000000  2.497220e+05  4.395006e+07
# max                6.000000              5.000000  9.741060e+07  3.001865e+08

# %%
a = matches.groupby('Home Team Name').sum()

# %%
sort=a.sort_values(by='Home Team Goals', ascending=False)
sort=sort.drop(columns=["RoundID", 'MatchID', 'Attendance', 'Year','Half-time Home Goals','Half-time Away Goals', 'Away Team Goals'])

# %%
plt.figure(figsize=(12,13))
plt.subplot(211)
sns.distplot(matches["Home Team Goals"],color="b",rug=True)
plt.xticks(np.arange(0,12,1))
plt.title("Distribution of Home Team Goals",color='b')


plt.subplot(212)
sns.distplot(matches["Away Team Goals"],color="r",rug=True)
plt.xticks(np.arange(0,9,1))
plt.title("Distribution of Away Team Goals",color='b')
plt.show()

# %%
matches.isnull().sum()
sns.set_style("darkgrid")

#removing duplicate rows for match id column 
matches = matches.drop_duplicates(subset="MatchID",keep="first")

#remob=ving null values
matches = matches[matches["Year"].notnull()]

att = matches.groupby("Year")["Attendance"].sum().reset_index()
att["Year"] = att["Year"].astype(int)
plt.figure(figsize=(12,7))
sns.barplot(att["Year"],att["Attendance"],linewidth=1,edgecolor="k"*len(att))
plt.grid(True)
plt.title("Attendence by year",color='b')
plt.show()

# %%
att1 = matches.groupby("Year")["Attendance"].mean().reset_index()
att1["Year"] = att1["Year"].astype(int)
plt.figure(figsize=(12,7))
ax = sns.pointplot(att1["Year"],att1["Attendance"],color="w")
ax.set_facecolor("k")
plt.grid(True,color="grey",alpha=.3)
plt.title("Average attendence by year",color='b')
plt.show()

# %%
plt.figure(figsize=(13,7))
winners["Year1"] = winners["Year"].astype(str)
ax = plt.scatter("Year1","GoalsScored",data=winners,
            c=winners["GoalsScored"],cmap="inferno",
            s=900,alpha=.7,
            linewidth=2,edgecolor="k",)

#plt.colorbar()
plt.xticks(winners["Year1"].unique())
plt.yticks(np.arange(60,200,20))
plt.title('Total goals scored by year',color='b')
plt.xlabel("year")
plt.ylabel("total goals scored")
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.barplot(winners["Year"],winners["MatchesPlayed"],linewidth=1,
            edgecolor="k"*len(winners),color="b",label="Total matches played")
sns.barplot(winners["Year"],winners["QualifiedTeams"],linewidth=1,
            edgecolor="k"*len(winners),color="r",label="Total qualified teams")
plt.legend(loc="best",prop={"size":13})
plt.title("Qualified teams by year",color='b')
plt.grid(True)
plt.ylabel("total matches and qualified teams by year")
plt.show()

# %%
h_att = matches.sort_values(by="Attendance",ascending=False)[:10]
h_att = h_att[['Year', 'Datetime','Stadium', 'City', 'Home Team Name',
              'Home Team Goals', 'Away Team Goals', 'Away Team Name', 'Attendance', 'MatchID']]
h_att["Stadium"] = h_att["Stadium"].replace('Maracan� - Est�dio Jornalista M�rio Filho',"Maracanã Stadium")
h_att["Datetime"] = h_att["Datetime"].str.split("-").str[0]
h_att["mt"] = h_att["Home Team Name"] + " .Vs.  " + h_att["Away Team Name"]

plt.figure(figsize=(10,9))
ax = sns.barplot(y =h_att["mt"],x = h_att["Attendance"],palette="gist_ncar",
                 linewidth = 1,edgecolor="k"*len(h_att))
plt.ylabel("match teams")
plt.xlabel("Attendance")
plt.title("Matches with highest number of attendace",color='b')
plt.grid(True)
for i,j in enumerate(" stadium : "+h_att["Stadium"]+" , Date :" + h_att["Datetime"]):
    ax.text(.7,i,j,fontsize = 12,color="white",weight = "bold")
plt.show()

# %%
tt_gl_h = matches.groupby("Home Team Name")["Home Team Goals"].sum().reset_index()
tt_gl_h.columns = ["team","goals"]

tt_gl_a = matches.groupby("Away Team Name")["Away Team Goals"].sum().reset_index()
tt_gl_a.columns = ["team","goals"]

total_goals = pd.concat([tt_gl_h,tt_gl_a],axis=0)
total_goals = total_goals.groupby("team")["goals"].sum().reset_index()
total_goals = total_goals.sort_values(by="goals",ascending =False)
total_goals["goals"] = total_goals["goals"].astype(int)

plt.figure(figsize=(10,12))
ax= sns.barplot("goals","team",data=total_goals[:20],palette="cool",
                linewidth=1,edgecolor="k"*20)

for i,j in enumerate("SCORED  " +total_goals["goals"][:20].astype(str) + "  GOALS"):
    ax.text(.7,i,j,fontsize = 10,color="k")

plt.title("Teams with highest fifa world cup goals",color='b')
plt.grid(True)
plt.show()
